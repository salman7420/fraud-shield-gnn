# %%
import pandas as pd
import sweetviz as sv

# %%
from src.preprocessing.base.base_builder import build_base

df_base = build_base()
print(df_base.head())
# Out:
# 2026-04-18 19:34:44,847 - INFO - src.preprocessing.base.base_builder - ==================================================
# 2026-04-18 19:34:44,848 - INFO - src.preprocessing.base.base_builder - Starting base dataset build pipeline
# 2026-04-18 19:34:44,848 - INFO - src.preprocessing.base.base_builder - ==================================================
# 2026-04-18 19:34:44,848 - INFO - src.preprocessing.base.base_builder - Step 1/6 — Loading raw data
# 2026-04-18 19:34:44,849 - INFO - src.data_ingestion.load_data - Loading Data From: /Users/salmanrasheed/Desktop/Projects/fraud-shield-gnn/data/raw/train_transaction.csv
# 2026-04-18 19:34:51,334 - INFO - src.data_ingestion.load_data - Loaded data with 590,540 rows and 394 columns
# 2026-04-18 19:34:51,336 - INFO - src.data_ingestion.load_data - Loading Data From: /Users/salmanrasheed/Desktop/Projects/fraud-shield-gnn/data/raw/train_identity.csv
# ...

# %%
df_base.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
#
#    card2  card3       card4  card5  ...  id_20  id_28     id_29  \
# 0    NaN  150.0    discover  142.0  ...    NaN    NaN       NaN
# 1  404.0  150.0  mastercard  102.0  ...    NaN    NaN       NaN
# 2  490.0  150.0        visa  166.0  ...    NaN    NaN       NaN
# 3  567.0  150.0  mastercard  117.0  ...    NaN    NaN       NaN
# 4  514.0  150.0  mastercard  102.0  ...  144.0    New  NotFound
#
#                  id_31 id_35 id_36  id_37  id_38  DeviceType  \
# 0                  NaN   NaN   NaN    NaN    NaN         NaN
# ...

# %%
import sweetviz as sv
import os
from src.utils.data_configs import BASE_DATA
from src.data_ingestion.load_data import load_data

df = load_data(BASE_DATA)

# Create reports folder if it doesn't exist
os.makedirs("../reports", exist_ok=True)

report = sv.analyze(
    df,
    target_feat="isFraud",
    pairwise_analysis="off"
)
report.show_html("../reports/eda_report.html")
# Out:
# 2026-04-18 19:36:17,237 - INFO - src.data_ingestion.load_data - Loading Data From: /Users/salmanrasheed/Desktop/Projects/fraud-shield-gnn/data/base/train_base.csv
# 2026-04-18 19:36:24,297 - INFO - src.data_ingestion.load_data - Loaded data with 590,540 rows and 360 columns
#                                              |          | [  0%]   00:00 -> (? left)
# Report ../reports/eda_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
